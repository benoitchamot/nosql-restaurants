# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create an instance of MongoClient
port = 27017
mongo = MongoClient(port=port)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### DataFrame creation and display function
# The function below is used to:
# 1. Convert the result to a Pandas DataFrame
# 2. Display the number of rows in the DataFrame
# 3. Display the first 10 rows of the DataFrame

# %%
def create_dataframe(results, verbose = False):
# Create a DataFrame from the results of a pymongo query
# Input: results of query (list of dictionaries)
# Input: boolean, set to True to print number of rows and display head (10)
# Output: pandas DataFrame

    # Convert the result to a Pandas DataFrame
    results_df = pd.DataFrame(results)

    if verbose:
        # Display the number of rows in the DataFrame
        print(f"There are {len(results_df)} rows in the DataFrame")

        # Display the first 10 rows of the DataFrame
        display(results_df.head(10))

    return results_df

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_score = 20
query = {'scores.Hygiene': hygiene_score}
results = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
doc_count = establishments.count_documents(query)
print(f"There are {doc_count} establishments with a Hygiene Score of {hygiene_score}")

# Display the first document in the results using pprint
print("\nFirst document:")
print("-----------")
pprint(results[0])
# Out:
# There are 41 establishments with a Hygiene Score of 20
#
# First document:
# -----------
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64e2fd1cb60896e10f941cea'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
# Display the number of rows in the DataFrame
# Display the first 10 rows of the DataFrame
df = create_dataframe(results, True)
# Out:
# There are 41 rows in the DataFrame
#                         _id   FHRSID  ChangesByServerID  \
# 0  64e2fd1cb60896e10f941cea   110681                  0
# 1  64e2fd1cb60896e10f94206b   612039                  0
# 2  64e2fd1cb60896e10f942374   730933                  0
# 3  64e2fd1cb60896e10f942572   172953                  0
# 4  64e2fd1cb60896e10f942573   172735                  0
# 5  64e2fd1cb60896e10f942f10   512854                  0
# 6  64e2fd1cb60896e10f943132  1537089                  0
# 7  64e2fd1db60896e10f94465d   155648                  0
# 8  64e2fd1db60896e10f944aa2  1012883                  0
# 9  64e2fd1db60896e10f9452b1   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000024532              Golden Palace
# 4             PI/000023858              Seaford Pizza
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3            Restaurant/Cafe/Canteen               1         5 South Street
# 4             Takeaway/sandwich shop            7844          4 High Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3     {'longitude': 0.101446, 'latitude': 50.770724}
# 4      {'longitude': 0.10202, 'latitude': 50.770885}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.437179            False
# 4  4620.421725            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %% [markdown]
# While working on this part of the assignment, I realised that several documents have a non-numerical value for their rating. I have isolated only the document with a valid (numerical) value for the analysis. The invalid documents are ignored from the query but left untouched in the database. The valid documents are updated to change the value from a strong to a floating number.

# %%
# Count the documents for which the establishment is awaiting inspection or publication
query = {'RatingValue':{'$regex':"Awaiting"}}
doc_count = establishments.count_documents(query)
print(f"There are {doc_count} establishments that are awaiting inspection or publication to get a rating")

# Count the documents for which the establishment is exempt
query = {'RatingValue':{'$regex':"Exempt"}}
doc_count = establishments.count_documents(query)
print(f"There are {doc_count} establishments that are exempted")

# Count the documents for which the establishment got a pass
query = {'RatingValue':{'$regex':"Pass"}}
doc_count = establishments.count_documents(query)
print(f"There are {doc_count} establishments that got a 'Pass")

# Isolate the documents that do not have an invalid rating status
status_awaiting1 = 'AwaitingInspection'
status_awaiting2 = 'Awaiting Inspection'
status_exempt = 'Exempt'
status_awaiting_publication = 'AwaitingPublication'
status_pass = 'Pass'

# Count documents with a valid (numerical) rating
documents_with_rating = {'RatingValue':{'$nin': [status_awaiting1, status_awaiting2, status_exempt, status_awaiting_publication, status_pass]}}
doc_count = establishments.count_documents(documents_with_rating)
print(f"There are {doc_count} establishments with a valid rating")

# Convert the rating value to a double when the value is numerical
update_query = [{'$set':{"RatingValue":{'$toDouble': "$RatingValue"}}}]
establishments.update_many(documents_with_rating, update_query)
# Out:
# There are 2115 establishments that are awaiting inspection or publication to get a rating
# There are 1883 establishments that are exempted
# There are 93 establishments that got a 'Pass
# There are 34695 establishments with a valid rating

# %% [markdown]
# I then could not find any document with LocalAuthorityName = London... So I decided to count the documents for each LocalAuthorityName and find the ones that could be listed as London.

# %%
# Count the number of documents for each LocalAuthorityName
match_query = {'$match': {'LocalAuthorityName': {'$regex': "London"}}}
group_query = {'$group': {'_id':'$LocalAuthorityName','count': {'$sum': 1}}}
sort_values = {'$sort': {'_id': 1}}
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
pprint(results)
# Out:
# [{'_id': 'City of London Corporation', 'count': 37}]

# %%
# Display the rating values for the establishments in London
location = 'London'
rating_value = 4

query = {'LocalAuthorityName': {'$regex': location}}

fields = {'BusinessName':1, 'RatingValue': 1, '_id':0}
results = list(establishments.find(query, fields))

print(f"There are {len(results)} establishments in {location}")
print('Names and ratings of establishments:\n--------------')
pprint(results)
# Out:
# There are 37 establishments in London
# Names and ratings of establishments:
# --------------
# [{'BusinessName': "Charlie's", 'RatingValue': 4.0},
#  {'BusinessName': 'Mv City Cruises Erasmus', 'RatingValue': 5.0},
#  {'BusinessName': 'Benfleet Motor Yacht Club', 'RatingValue': 4.0},
#  {'BusinessName': 'Gourmet Kitchen', 'RatingValue': 3.0},
#  {'BusinessName': 'Coombs Catering t/a The Lock and Key', 'RatingValue': 5.0},
#  {'BusinessName': 'Tilbury Seafarers Centre', 'RatingValue': 5.0},
#  {'BusinessName': 'Mv Valulla', 'RatingValue': 5.0},
#  {'BusinessName': 'Froottree', 'RatingValue': 'AwaitingInspection'},
#  {'BusinessName': 'Tereza Joanne', 'RatingValue': 5.0},
#  {'BusinessName': 'Brick Lane Brews', 'RatingValue': 4.0},
#  {'BusinessName': 'Pret A Manger', 'RatingValue': 2.0},
#  {'BusinessName': 'The Nuance Group (UK) Limited', 'RatingValue': 5.0},
#  {'BusinessName': 'WH Smith', 'RatingValue': 5.0},
#  {'BusinessName': 'City Bar & Grill', 'RatingValue': 5.0},
#  {'BusinessName': 'Cabin Bar', 'RatingValue': 2.0},
#  {'BusinessName': 'Caffè Nero', 'RatingValue': 5.0},
#  {'BusinessName': 'Jet Centre', 'RatingValue': 5.0},
#  {'BusinessName': 'Mv Sunborn Yacht Hotel', 'RatingValue': 5.0},
#  {'BusinessName': 'Good Hotel London', 'RatingValue': 5.0},
#  {'BusinessName': 'La Nonna lina', 'RatingValue': 4.0},
#  {'BusinessName': 'Wake Up Docklands Limited', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Venus Clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Moon clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Typhoon clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Meteor clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Jupiter clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Mercury clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Tornado clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Neptune clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Cyclone clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Hurricane clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Galaxy clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Sun clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Monsoon clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'Mv Storm Clipper', 'RatingValue': 5.0},
#  {'BusinessName': 'Canary Wharf 1V', 'RatingValue': 5.0},
#  {'BusinessName': 'MV Aurora clipper', 'RatingValue': 5.0}]

# %% [markdown]
# I had to use 'City of London Corporation' instead of just 'London'. To avoid any doubt, I used `$regex` in my query.

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
location = 'London'
rating_value = 4

query = {'LocalAuthorityName': {'$regex': location}, 'RatingValue': {'$gte' : rating_value}}
results = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
doc_count = establishments.count_documents(query)
print(f"There are {doc_count} establishments in {location} with a Rating Value >= {rating_value}")

# Display the first document in the results using pprint
if results:
    print("\nFirst document:")
    print("-----------")
    pprint(results[0])
else:
    print('No document found.')
# Out:
# There are 33 establishments in London with a Rating Value >= 4
#
# First document:
# -----------
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4.0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64e2fd1cb60896e10f943705'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
# Display the number of rows in the DataFrame
# Display the first 10 rows of the DataFrame
df = create_dataframe(results, True)
# Out:
# There are 33 rows in the DataFrame
#                         _id   FHRSID  ChangesByServerID  \
# 0  64e2fd1cb60896e10f943705   621707                  0
# 1  64e2fd1cb60896e10f943a29  1130836                  0
# 2  64e2fd1db60896e10f944576   293783                  0
# 3  64e2fd1db60896e10f945377  1315095                  0
# 4  64e2fd1db60896e10f945379   294474                  0
# 5  64e2fd1db60896e10f945a80   294900                  0
# 6  64e2fd1db60896e10f947b8e   293756                  0
# 7  64e2fd1db60896e10f947f56   878523                  0
# 8  64e2fd1db60896e10f947f68   293772                  0
# 9  64e2fd1db60896e10f947f69   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

lat_min = latitude - degree_search
lat_max = latitude + degree_search

lon_min = longitude - degree_search
lon_max = longitude + degree_search

query = {'geocode.longitude': {'$gte': lon_min, '$lte': lon_max},
        'geocode.latitude': {'$gte': lat_min, '$lte': lat_max},
        'RatingValue': 5
        }

sort = [('scores.Hygiene',1)]

limit = 5

results = establishments.find(query).sort(sort).limit(limit)
results_list = list(results)

# Print the results
pprint(results_list)
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5.0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64e2fd1db60896e10f94754a'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5.0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64e2fd1db60896e10f94755f'),
#   'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '17 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.975587048333,
#   'FHRSID': 909912,
#   'LocalAuthorityBusinessID': 'PI/000201100',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5.0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64e2fd1db60896e10f947565'),
#   'geocode': {'latitude': 51.4871632, 'longitude': 0.0916256},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5.0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64e2fd1db60896e10f94751d'),
#   'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5.0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64e2fd1db60896e10f94752a'),
#   'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert the result to a Pandas DataFrame
# Display the number of rows in the DataFrame
# Display the first 10 rows of the DataFrame
df = create_dataframe(results_list, True)
# Out:
# There are 5 rows in the DataFrame
#                         _id   FHRSID  ChangesByServerID  \
# 0  64e2fd1db60896e10f94754a   694609                  0
# 1  64e2fd1db60896e10f94755f   695241                  0
# 2  64e2fd1db60896e10f947565   909912                  0
# 3  64e2fd1db60896e10f94751d   695223                  0
# 4  64e2fd1db60896e10f94752a  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                      Retailers - other            4613
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                         Mobile caterer            7846
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1               Plumstead Manor School Old Mill Road
# 2                                   17 Lakedale Road
# 3                    144 - 146 Plumstead High Street
# 4  Restaurant And Premises 107A Plumstead High St...
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 3  {'longitude': 0.0924199968576431, 'latitude': ...
# 4  {'longitude': 0.0925370007753372, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.974010            False
# 2  4646.975587            False
# 3  4646.946071            False
# 4  4646.955931            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %%
# Print the Top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score
normalised_pd = pd.json_normalize(results_list)
print("Top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score")
normalised_pd[['BusinessName','scores.Hygiene','RatingValue']].head(5)
# Out:
# Top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score
#                           BusinessName  scores.Hygiene  RatingValue
# 0                            Volunteer               0          5.0
# 1              Plumstead Manor Nursery               0          5.0
# 2      Lumbini Grocery Ltd T/A Al-Iman               0          5.0
# 3                              Iceland               0          5.0
# 4  Howe and Co Fish and Chips - Van 17               0          5.0

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id':'$LocalAuthorityName','count': {'$sum': 1}}}
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"Number of locations with establishments with hygiene score of 0: {len(results)}")

# Print the first 10 results
print("First 10 results:\n-----------")
pprint(results[:10])
# Out:
# Number of locations with establishments with hygiene score of 0: 55
# First 10 results:
# -----------
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
# Display the number of rows in the DataFrame
# Display the first 10 rows of the DataFrame
df = create_dataframe(results, True)
# Out:
# There are 55 rows in the DataFrame
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542

# %%
# Show the number of establishments with Hygiene Score of 0 in a bar chart
df = df.sort_values('count', ascending=True)
df.plot.barh(x='_id', figsize = (8,8), xlabel='Local Authority', ylabel='Number of establishments', title="Establishments with Hygiene Score of 0", legend=False)
plt.savefig('Output/Q4_Establishments_with_Hygiene_Score_of_0.png')
plt.show()
